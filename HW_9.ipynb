# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %% [markdown]
# #### Задание 1.
# <br>Даны значения величины заработной платы заемщиков банка (zp) и значения их
# поведенческого кредитного скоринга (ks): zp = [35, 45, 190, 200, 40, 70, 54, 150, 120,
# 110], ks = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832]. Используя
# математические операции, посчитать коэффициенты линейной регрессии, приняв
# за X заработную плату (то есть, zp - признак), а за y - значения скорингового балла
# (то есть, ks - целевая переменная). Произвести расчет как с использованием
# intercept, так и без.
# <br>b = cov(x, y) / var(x)
# <br>a = mean_y - b * mean_x

# %%
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

# %%
mean_zp = np.mean(zp)
mean_ks = np.mean(ks)
n = len(zp)
cov = np.sum((zp - mean_zp) * (ks - mean_ks)) / (n - 1)
var = np.sum((zp - mean_zp)** 2) / (n - 1)
b = cov / var
print(f'Коэффициент наклона (b) без intercept = {round(b, 3)}')
# Out:
# Коэффициент наклона (b) без intercept = 2.621

# %%
mean_zpks = np.mean(zp * ks)
mean_zp2 = np.mean(zp ** 2)
b1 = (mean_zpks - mean_zp * mean_ks) / (mean_zp2 - mean_zp ** 2)
print(f'Коэффициент наклона (b): {round(b1, 3)}')
b0 = mean_ks - b * mean_zp
print(f'Intercept (a): {round(b0, 3)}')
# Out:
# Коэффициент наклона (b): 2.621
# Intercept (a): 444.177

# %% [markdown]
# #### Задача 2.
# Посчитать коэффициент линейной регрессии при заработной плате (zp), используя
# градиентный спуск (без intercept).

# %%
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])
slope = 0
learning_rate = 0.0001
interactions = 100
# # среднеквадратичная ошибка
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)
# # градиент
def gradient(zp, ks, slope):
    return np.mean((slope * zp - ks) * zp)
# # градиентный спуск
for i in range (interactions):
    slope -= learning_rate * gradient (zp, ks, slope)
    mse = mean_squared_error (ks, slope * zp)
    print(f'Итерация {i+1}: Коэффициент склонности = {slope:.2f}, Среднеквадратичная ошибка = {mse:.4f}')
    
print(f'Коэффициент склонности: {slope:.2f}')
# Out:
# Итерация 1: Коэффициент склонности = 8.11, Среднеквадратичная ошибка = 124679.7700
# Итерация 2: Коэффициент склонности = 5.05, Среднеквадратичная ошибка = 66238.7352
# Итерация 3: Коэффициент склонности = 6.21, Среднеквадратичная ошибка = 57903.4613
# Итерация 4: Коэффициент склонности = 5.77, Среднеквадратичная ошибка = 56714.6255
# Итерация 5: Коэффициент склонности = 5.94, Среднеквадратичная ошибка = 56545.0654
# Итерация 6: Коэффициент склонности = 5.87, Среднеквадратичная ошибка = 56520.8815
# Итерация 7: Коэффициент склонности = 5.90, Среднеквадратичная ошибка = 56517.4322
# Итерация 8: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.9403
# Итерация 9: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8701
# Итерация 10: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8601
# Итерация 11: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8587
# Итерация 12: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 13: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 14: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 15: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 16: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 17: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 18: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 19: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 20: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 21: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 22: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 23: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 24: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 25: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 26: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 27: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 28: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 29: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 30: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 31: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 32: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 33: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 34: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 35: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 36: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 37: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 38: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 39: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 40: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 41: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 42: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 43: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 44: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 45: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 46: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 47: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 48: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 49: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 50: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 51: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 52: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 53: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 54: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 55: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 56: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 57: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 58: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 59: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 60: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 61: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 62: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 63: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 64: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 65: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 66: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 67: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 68: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 69: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 70: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 71: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 72: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 73: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 74: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 75: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 76: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 77: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 78: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 79: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 80: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 81: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 82: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 83: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 84: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 85: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 86: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 87: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 88: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 89: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 90: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 91: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 92: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 93: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 94: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 95: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 96: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 97: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 98: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 99: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Итерация 100: Коэффициент склонности = 5.89, Среднеквадратичная ошибка = 56516.8584
# Коэффициент склонности: 5.89

# %% [markdown]
# #### Задача 3.
# Произвести вычисления как в пункте 2, но с вычислением intercept. Учесть, что
# изменение коэффициентов должно производиться на каждом шаге одновременно (то
# есть изменение одного коэффициента не должно влиять на изменение другого во
# время одной итерации).

# %%
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])
# Начальные коэффициенты
w = 0
b = 0
# Скорость обучения
alfa = 0.00001
# Количество итераций
n_iter = 100
# Среднеквадратичная ошибка
def compute_mse(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)
# Градиентный спуск
for i in range(n_iter):
    y_predict = w * zp + b
    errors = y_predict - ks
    dw = (2 / len (zp)) * np.dot(zp, errors)
    db = (2 / len (zp)) * np.sum(errors)
    w -= alfa * dw
    b -= alfa * db
    if i % 10 == 0:
        mse = compute_mse(ks, y_predict)
        print (f'Interaction {i}: MSE = {mse}, w = {w}, b = {b}')
print(f'Итоговые значения коэффициента при zp = {w}, b = {b}')
# Out:
# Interaction 0: MSE = 534426.9, w = 1.6228340000000003, b = 0.014198000000000002
# Interaction 10: MSE = 57259.82360268264, w = 5.7194781711796105, b = 0.06688272629234994
# Interaction 20: MSE = 56498.139442450076, w = 5.882447821449009, b = 0.09061272592544278
# Interaction 30: MSE = 56491.864262783456, w = 5.888778079207038, b = 0.1131886474254337
# Interaction 40: MSE = 56486.787405548675, w = 5.8888709452719405, b = 0.1357175160728701
# Interaction 50: MSE = 56481.712962490434, w = 5.88871544571302, b = 0.15824341380550042
# Interaction 60: MSE = 56476.63903727406, w = 5.888550064280519, b = 0.18076809602714117
# Interaction 70: MSE = 56471.565626840435, w = 5.8883842974261364, b = 0.20329163269384737
# Interaction 80: MSE = 56466.49273113264, w = 5.88821852329933, b = 0.22581402664693526
# Interaction 90: MSE = 56461.42035009838, w = 5.888052756957648, b = 0.24833527805520117
# Итоговые значения коэффициента при zp = 5.887903574417696, b = 0.2686034274984876
